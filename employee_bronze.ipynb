# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_emp=spark.read.format('csv').option('header',True).load('/Volumes/workspace/default/datasets/EMPLOAD.csv')
df_emp.display()

# %%
df_emp.write.saveAsTable('emp_bronze')
